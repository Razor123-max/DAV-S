# %%
from pandas import read_csv                                                                    
from matplotlib import pyplot     
from statsmodels.graphics.tsaplots import plot_acf    
from statsmodels.graphics.tsaplots import plot_pacf

# %%
series=read_csv('Salary_Data.csv')                                                          
series.plot()                                                                                  
pyplot.show()

# %%
series=read_csv('Salary_data.csv', header=0, index_col=0)
plot_acf(series)
pyplot.show()

# %%
series=read_csv('Salary_data.csv', header=0, index_col=0)
plot_pacf(series)
pyplot.show()
